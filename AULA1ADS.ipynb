# %% [markdown]
# <a href="https://colab.research.google.com/github/eusettee/Curriculo-HeitorSette/blob/main/AULA1ADS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome=input("Digite seu nome:")
idade= int(input("Digite sua idade:"))
altura=float(input("Digite sua altura:"))

print (nome, "tem", idade, "e a altura de", altura)
# Out:
# Digite seu nome:sette
# Digite sua idade:16
# Digite sua altura:1.80
# sette tem 16 e a altura de 1.8

# %%
aluno=input("Digite o nome do estudante")
nota1=float(input("Digite a primeira nota:"))
nota2=float(input("Digite a segunda nota:"))

media = (nota1+nota2)/2

print("A média do aluno", aluno, "é", media)
# Out:
# Digite o nome do estudantedad
# Digite a primeira nota:23
# Digite a segunda nota:53
# A média do aluno dad é 38.0

# %%
lado=float(input("Digite o valor do lado do quadrado:"))
area=lado*lado
print(f"A área do quadrado é {lado} é {lado**2}").
# Out:
# Digite o valor do lado do quadrado:5
# A área do quadrado é 5.0 é 25.0

# %%
base= float(input("Digite o valor da base do quadrilatero:"))
altura= float(input("Digite o valor da altura do quadrilatero:"))

if(base != altura):
    print("O quadrilatero é um retangulo")
else:
    print("O quadrilatero é um quadrado")
# Out:
# Digite o valor da base do quadrilatero:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_717/1078083186.py in <cell line: 0>()
# ----> 1 base= float(input("Digite o valor da base do quadrilatero:"))
#       2 altura= float(input("Digite o valor da altura do quadrilatero:"))
#       3
#       4 if(base != altura):
#       5     print("O quadrilatero é um retangulo")
#
# ValueError: could not convert string to float: ''

# %%
print(f"LISTA DE FILMES\n1.Senhor dos aneis\n2.Bater ou correr\n3.IT")
filme=input("Digite um filme da lista").lower()
match(filme):
    case "senhor dos aneis":
        print("O senhor dos aneis é um filme de fantasia")
    case "bater ou correr":
        print("Bater ou correr é um filme de comédia")
    case "IT"
        print("IT é um filme de terror")
    case _:
        print("Digite apenas filmes da lista")
# Out:
# LISTA DE FILMES
# 1.Senhor dos aneis
# 2.Bater ou correr
# 3.IT
# Digite um filme da listaIT
# IT é um filme de terror

# %%
nome=input("Digite seu nome:")
cidade=input("Digite o nome da sua cidade")

print("seu nome é", nome, "e você mora em", cidade, ".")
# Out:
# Digite seu nome:sdjajda
# Digite o nome da sua cidadehdhsahda
# seu nome é sdjajda e você mora em hdhsahda .

# %%
dianasc=input("Qual o seu dia de nascimento?")
mesnasc=input("Qual o seu mês de nascimento?")
anonasc=input("Qual o seu ano de nascimento?")

print()
# Out:
# Qual o seu dia de nascimento?31
# Qual o seu mês de nascimento?10
# Qual o seu ano de nascimento?2006
# Sua data de nascimento é: 31/10/2006
